# %% [markdown]
# # Web Scraping Lab

# %% [markdown]
# ## Questions
#
# Resident Advisor is an events listing website for electronic music.
#
# Go to www.residentadvisor.net/events.  This is the url we'll be starting with for this lab.  For question 1, just use this url.  In the next two, you'll use country and region in the format: http://www.residentadvisor.net/country/region/ i.e. us/losangeles/.  Be sure to explore the web pages in both the browswer and the HTML file.  You'll need both to really understand what's going on.
#
# 1. Which venues are hosting events this week?
# 2. Make a function which returns the events this week given region and country (this will take two arguments)
#     - return the event name, link, and list of artists
#     - function returns list of ['event name', 'www.linkaddress.com', ['artist1','artist2','artist3']]
# 3. Create a function which returns the users attending
# 4. Bonus

# %% [markdown]
# ### Question 1 - Which venues are hosting events this week?

# %%
import requests
from bs4 import BeautifulSoup

r = requests.get('https://www.residentadvisor.net/events')
c = r.content
soup = BeautifulSoup(c, 'html.parser')

# %%
events = soup.find_all('article', attrs={'class': 'event-item'})

# %%
events[0]
# Out:
# <article class="event-item clearfix " itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2018-11-07T00:00" itemprop="startDate">2018-11-07T00:00</time></span><a href="/events/1171717"><img height="76" src="/images/events/flyer/2018/11/us-1107-1171717-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1171717" itemprop="url" title="Event details of Love Games with Lauren Murada and Finn Jones">Love Games with Lauren Murada and Finn Jones</a> <span>at <a href="/club.aspx?id=97606">Good Room</a></span></h1><div class="grey event-lineup">Good Room presents, Love Games with, Lauren Murada and Finn Jones</div><p class="attending"><span>8</span> Attending</p></div></article>

# %%
events[3].div.span.text[3:]
# Out:
# '101bklyn'

# %%
try:
    print(events[1].p.text.split(' ')[0])
except AttributeError:
    pass
# Out:
# 5

# %%
# int(attendees[3].text.split(' ')[0])
# Out:
# 3

# %%
def find_venues(soup):
    events = soup.find_all('article', attrs={'class': 'event-item'})
    event_venues = []
    for event in events:
        event_venues.append(event.div.span.text[3:])
    return event_venues

# %%
find_venues(soup)
# Out:
# ['Good Room',
#  'Bossa Nova Civic Club',
#  'Output',
#  '101bklyn',
#  'TBA Brooklyn',
#  'Cielo',
#  'Elsewhere',
#  'Jing Fong Restaurant',
#  'Alphaville',
#  'Output',
#  'Good Room',
#  'The Kings Hall',
#  'Nowadays',
#  'Future Space',
#  'Mood Ring',
#  'Output',
#  'TBA Brooklyn',
#  'Elsewhere',
#  'Le Bain',
#  '101bklyn',
#  'Bar 13',
#  'Public Arts',
#  'H0L0',
#  'Sugar Hill Disco',
#  'Better Days',
#  'Good Room',
#  'TBA - Brooklyn',
#  'Output',
#  '99 Scott Ave',
#  'Elsewhere',
#  'H0L0',
#  'Nowadays',
#  'The Hart',
#  'Avant Gardner',
#  'TBA - Brooklyn',
#  'Schimanski',
#  '101bklyn',
#  'Chelsea Music Hall',
#  'Rose Gold',
#  'TBA Brooklyn',
#  'Tsunami Bass Brown Note',
#  'Analog Bkny',
#  'Knockdown Center',
#  'Le Bain',
#  'Jupiter Disco',
#  'Bossa Nova Civic Club',
#  'TBA - Brooklyn',
#  'Mood Ring',
#  'TBA Brooklyn',
#  '291 Hooper St',
#  'Tropicana',
#  'Sutherland - Three Dollar Bill',
#  'Black Flamingo',
#  'El Cortez / The Safari Room',
#  'Avant Gardner',
#  '99 Scott Ave',
#  'Elsewhere',
#  'Avant Gardner',
#  'Nowadays',
#  'TBA - Brooklyn',
#  'TBA - New York',
#  'TBA - Brooklyn',
#  'Good Room',
#  'Chelsea Music Hall',
#  'House Of Yes',
#  'Rose Gold',
#  '101bklyn',
#  'Unnamed Gallery',
#  'Studio 299',
#  'Eris',
#  'Black Flamingo',
#  'Output',
#  'Bossa Nova Civic Club',
#  'Ponyboy',
#  'Sunnyvale',
#  'Nublu',
#  'Le Bain',
#  'TBA Brooklyn',
#  'Japan Society',
#  'Forest City Lodge 180',
#  'Sutherland - Three Dollar Bill',
#  "John's House of Music",
#  'The Hart',
#  'Good Room',
#  'Studio 299',
#  'Pioneer Works',
#  'House Of Yes',
#  'Output',
#  'Cielo',
#  'Jupiter Disco',
#  'TBA Brooklyn',
#  'TBA Brooklyn',
#  'Bossa Nova Civic Club',
#  'Trans Pecos']

# %%
event_venues
# Out:
# ['Good Room',
#  'Bossa Nova Civic Club',
#  'Output',
#  '101bklyn',
#  'TBA Brooklyn',
#  'Cielo',
#  'Elsewhere',
#  'Jing Fong Restaurant',
#  'Alphaville',
#  'Output',
#  'Good Room',
#  'The Kings Hall',
#  'Nowadays',
#  'Future Space',
#  'Mood Ring',
#  'Output',
#  'TBA Brooklyn',
#  'Elsewhere',
#  'Le Bain',
#  'Bar 13',
#  '101bklyn',
#  'Public Arts',
#  'H0L0',
#  'Sugar Hill Disco',
#  'Better Days',
#  'Good Room',
#  'Output',
#  '99 Scott Ave',
#  'Elsewhere',
#  'H0L0',
#  'Nowadays',
#  'The Hart',
#  'Avant Gardner',
#  'Schimanski',
#  '101bklyn',
#  'Chelsea Music Hall',
#  'Rose Gold',
#  'TBA Brooklyn',
#  'Tsunami Bass Brown Note',
#  'Analog Bkny',
#  'Knockdown Center',
#  'Le Bain',
#  'Jupiter Disco',
#  'Bossa Nova Civic Club',
#  'Mood Ring',
#  'TBA Brooklyn',
#  '291 Hooper St',
#  'Tropicana',
#  'Sutherland - Three Dollar Bill',
#  'Black Flamingo',
#  'El Cortez / The Safari Room',
#  'Avant Gardner',
#  '99 Scott Ave',
#  'Elsewhere',
#  'Avant Gardner',
#  'Nowadays',
#  'Good Room',
#  'Chelsea Music Hall',
#  'House Of Yes',
#  'Rose Gold',
#  '101bklyn',
#  'Unnamed Gallery',
#  'Studio 299',
#  'Eris',
#  'Black Flamingo',
#  'Output',
#  'Bossa Nova Civic Club',
#  'Sunnyvale',
#  'Nublu',
#  'Le Bain',
#  'TBA Brooklyn',
#  'Japan Society',
#  'Forest City Lodge 180',
#  'Sutherland - Three Dollar Bill',
#  "John's House of Music",
#  'The Hart',
#  'Good Room',
#  'Studio 299',
#  'Pioneer Works',
#  'House Of Yes',
#  'Output',
#  'Cielo',
#  'Jupiter Disco',
#  'TBA Brooklyn',
#  'TBA Brooklyn',
#  'Bossa Nova Civic Club',
#  'Trans Pecos']

# %% [markdown]
# Your solution output should look like: '101bklyn', '291 Hooper St', '99 Scott Ave','Alphaville', 'Analog Bkny'...

# %% [markdown]
# ### Question 2 - Write a function to which returns the events this week given region and country.

# %%
def find_events(country, region):
    r = requests.get(f'https://www.residentadvisor.net/events/{country}/{region}')
    c = r.content
    soup = BeautifulSoup(c, 'html.parser')
    return find_venues(soup)

# %%
# you should be able to output something like this
find_events('us','sanfrancisco')
# Out:
# ['F8 1192 Folsom',
#  'Phonobar',
#  'Peacock Lounge',
#  'The EndUp',
#  'F8 1192 Folsom',
#  'Public Works',
#  'The Regency',
#  'Public Works',
#  'F8 1192 Folsom',
#  'Halcyon',
#  'The Great Northern',
#  'Mezzanine',
#  'Phonobar',
#  'Monarch',
#  'Audio SF',
#  'Driftwood',
#  'Hawthorn',
#  'Monarch',
#  'Public Works Oddjob Loft',
#  'The Great Northern',
#  'Halcyon',
#  'Audio SF',
#  'Brix 581',
#  'Wish',
#  'Halcyon',
#  'Audio SF',
#  'Mezzanine',
#  'Monarch',
#  'F8 1192 Folsom',
#  'Monroe',
#  'Audio SF']

# %% [markdown]
# ### Question 3 - Create a function which returns the numbers of users attending each event this week, given country and region.  Then plot a histogram

# %%
def users_attending(country, region):
    
    r = requests.get(f'https://www.residentadvisor.net/events/{country}/{region}')
    c = r.content
    soup = BeautifulSoup(c, 'html.parser')
    
    # find venues
    venue_list = find_events(country,region)
    
    # set each event's value
    attendees = soup.find_all('p', attrs={'class': 'attending'})
    
    
    print(venue_list)

# %%
users_attending('us','newyork')
# Out:
# ['Good Room', 'Bossa Nova Civic Club', 'Output', '101bklyn', 'TBA Brooklyn', 'Cielo', 'Elsewhere', 'Jing Fong Restaurant', 'Alphaville', 'Output', 'Good Room', 'The Kings Hall', 'Nowadays', 'Future Space', 'Mood Ring', 'Output', 'TBA Brooklyn', 'Elsewhere', 'Le Bain', '101bklyn', 'Bar 13', 'Public Arts', 'H0L0', 'Sugar Hill Disco', 'Better Days', 'Good Room', 'Output', '99 Scott Ave', 'Elsewhere', 'H0L0', 'Nowadays', 'The Hart', 'Avant Gardner', 'Schimanski', '101bklyn', 'Chelsea Music Hall', 'Rose Gold', 'TBA Brooklyn', 'Tsunami Bass Brown Note', 'Analog Bkny', 'Knockdown Center', 'Le Bain', 'Jupiter Disco', 'Bossa Nova Civic Club', 'Mood Ring', 'TBA Brooklyn', '291 Hooper St', 'Tropicana', 'Sutherland - Three Dollar Bill', 'Black Flamingo', 'El Cortez / The Safari Room', 'Avant Gardner', '99 Scott Ave', 'Elsewhere', 'Avant Gardner', 'Nowadays', 'Good Room', 'Chelsea Music Hall', 'House Of Yes', 'Rose Gold', '101bklyn', 'Unnamed Gallery', 'Studio 299', 'Eris', 'Black Flamingo', 'Output', 'Bossa Nova Civic Club', 'Sunnyvale', 'Nublu', 'Le Bain', 'TBA Brooklyn', 'Japan Society', 'Forest City Lodge 180', 'Sutherland - Three Dollar Bill', "John's House of Music", 'The Hart', 'Good Room', 'Studio 299', 'Pioneer Works', 'House Of Yes', 'Output', 'Cielo', 'Jupiter Disco', 'TBA Brooklyn', 'TBA Brooklyn', 'Bossa Nova Civic Club', 'Trans Pecos']

# %%
# you should be able to output something like this
users_attending('us','newyork')[:10]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-9307b3bd1934> in <module>()
#       1 # you should be able to output something like this
# ----> 2 users_attending('us','newyork')[:10]
#
# TypeError: unhashable type: 'slice'

# %%
#now use the function to make a histogram
import plotly.offline as offline
import plotly.graph_objs as go

offline.init_notebook_mode()

offline.iplot([go.Histogram(x = users_attending('jp','tokyo'))])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-41-aaeca8bc46d1> in <module>()
#       1 #now use the function to make a histogram
# ----> 2 import plotly.offline as offline
#       3 import plotly.graph_objs as go
#       4
#       5 offline.init_notebook_mode()
#
# ModuleNotFoundError: No module named 'plotly'

# %% [markdown]
# ## Bonus: Build object relations between artists, venues, and events with sqlalchemy!
# Think about what each table should include - URLs, dates, etc.
